# %% [markdown]
# ## Import modules

# %%
import numpy as np
import os
from matplotlib import pyplot as plt
import pybasic

# %% [markdown]
# ## Declare image directory paths

# %%
path_to_demo_examples = 'path/to/demoexamples/'
path_to_demo_examples = 'C:/Users/Loren/Documents/Basic_Examples/Demoexamples/' #example
wsi_path = os.path.join(path_to_demo_examples, 'WSI_Brain/Uncorrected_tiles')

# %% [markdown]
# ## Import image sequence

# %%
D = pybasic.tools.load_data(wsi_path, '.tif', working_size=(128, 128), interpolation_method='bilinear')
# Out:
# Loading image sequence...
# 0 / 63
# 10 / 63
# 20 / 63
# 30 / 63
# 40 / 63
# 50 / 63
# 60 / 63

# %% [markdown]
# ## Run BaSiC

# %%
flatfield, darkfield = pybasic.basic(D, segmentation=None, darkfield=True)
# Out:
# Reweighting Iteration 1
# Iteration 1  |W|_0  1 |E1|_0 0  stopCriterion 0.703859190321617 B1_offset 0.0
# Iteration 2  |W|_0  1 |E1|_0 0  stopCriterion 0.2543805690974584 B1_offset 0.0
# Iteration 3  |W|_0  4 |E1|_0 0  stopCriterion 0.22881252380638228 B1_offset 0.21879631549794992
# Iteration 4  |W|_0  4 |E1|_0 78  stopCriterion 0.16222452173263624 B1_offset 0.21879631549794992
# Iteration 5  |W|_0  7 |E1|_0 158  stopCriterion 0.13204983079544888 B1_offset 0.21911615672015333
# Iteration 6  |W|_0  12 |E1|_0 221  stopCriterion 0.11454503015072652 B1_offset 0.21933799805582913
# Iteration 7  |W|_0  12 |E1|_0 270  stopCriterion 0.1087721933246889 B1_offset 0.21950682849819908
# Iteration 8  |W|_0  17 |E1|_0 315  stopCriterion 0.10572015147657751 B1_offset 0.2198530106137255
# Iteration 9  |W|_0  25 |E1|_0 392  stopCriterion 0.10302749405458164 B1_offset 0.22037760124761183
# Iteration 10  |W|_0  38 |E1|_0 1796  stopCriterion 0.09872585910246662 B1_offset 0.22066692488744705
# Iteration 11  |W|_0  54 |E1|_0 11416  stopCriterion 0.08275807823017857 B1_offset 0.22048516754444003
# Iteration 12  |W|_0  72 |E1|_0 27826  stopCriterion 0.05729996891035445 B1_offset 0.0
# Iteration 13  |W|_0  95 |E1|_0 40426  stopCriterion 0.03935030634427966 B1_offset 0.22007307752691144
# Iteration 14  |W|_0  116 |E1|_0 55877  stopCriterion 0.031963830066303975 B1_offset 0.22017606960110123
# Iteration 15  |W|_0  153 |E1|_0 87979  stopCriterion 0.025188097573696465 B1_offset 0.22012400696917353
# Iteration 16  |W|_0  198 |E1|_0 139527  stopCriterion 0.01819034401938966 B1_offset 0.22012453833049364
# Iteration 17  |W|_0  241 |E1|_0 201715  stopCriterion 0.012316386640596914 B1_offset 0.22018486821678604
# Iteration 18  |W|_0  282 |E1|_0 264382  stopCriterion 0.007964267415123991 B1_offset 0.2202240274942833
# Iteration 19  |W|_0  288 |E1|_0 319946  stopCriterion 0.005118875783657062 B1_offset 0.22023306081738234
# Iteration 20  |W|_0  299 |E1|_0 368030  stopCriterion 0.0033707697097709235 B1_offset 0.22025053269113365
# Iteration 21  |W|_0  307 |E1|_0 411486  stopCriterion 0.0022970624109746266 B1_offset 0.22027510335932524
# Iteration 22  |W|_0  304 |E1|_0 455597  stopCriterion 0.0016107821386346518 B1_offset 0.2202995615815369
# Iteration 23  |W|_0  308 |E1|_0 509227  stopCriterion 0.0011371402063079282 B1_offset 0.22031331173502472
# Iteration 24  |W|_0  310 |E1|_0 576717  stopCriterion 0.0007999117832715529 B1_offset 0.22031830077313008
# Iteration 25  |W|_0  318 |E1|_0 658489  stopCriterion 0.0005410542710510303 B1_offset 0.2203220173249642
# Iteration 26  |W|_0  321 |E1|_0 742315  stopCriterion 0.0003459761538579048 B1_offset 0.22032398444560106
# Iteration 27  |W|_0  327 |E1|_0 817357  stopCriterion 0.00021185331348089914 B1_offset 0.22032517169707788
# Iteration 28  |W|_0  333 |E1|_0 878248  stopCriterion 0.00012446330659796374 B1_offset 0.22032573831441293
# Iteration 29  |W|_0  334 |E1|_0 924479  stopCriterion 7.12541948296943e-05 B1_offset 0.22032593191171473
# Iteration 30  |W|_0  335 |E1|_0 958081  stopCriterion 3.984186976992694e-05 B1_offset 0.2203259290560457
# Iteration 31  |W|_0  336 |E1|_0 981509  stopCriterion 2.207308575075286e-05 B1_offset 0.22032589873297034
# Iteration 32  |W|_0  337 |E1|_0 997775  stopCriterion 1.2112112134281465e-05 B1_offset 0.22032587792469877
# Iteration 33  |W|_0  339 |E1|_0 1008938  stopCriterion 6.627981582880723e-06 B1_offset 0.22032587070727516
# Iteration 34  |W|_0  339 |E1|_0 1016305  stopCriterion 3.6497210626487996e-06 B1_offset 0.22032586860790745
# Iteration 35  |W|_0  339 |E1|_0 1021384  stopCriterion 2.014811915894044e-06 B1_offset 0.22032586735282647
# Iteration 36  |W|_0  339 |E1|_0 1024858  stopCriterion 1.1204288072056258e-06 B1_offset 0.2203258671577794
# Iteration 37  |W|_0  341 |E1|_0 1027210  stopCriterion 6.131428405402807e-07 B1_offset 0.2203258679138876
# Reweighting Iteration 2
# Iteration 1  |W|_0  1 |E1|_0 236  stopCriterion 0.6859247857123779 B1_offset 0.0
# Iteration 2  |W|_0  1 |E1|_0 279  stopCriterion 0.2111749162420601 B1_offset 0.0
# Iteration 3  |W|_0  4 |E1|_0 783  stopCriterion 0.1763172988684461 B1_offset 0.21944459790643536
# Iteration 4  |W|_0  4 |E1|_0 2300  stopCriterion 0.12682853224298324 B1_offset 0.2195169409424005
# Iteration 5  |W|_0  8 |E1|_0 5212  stopCriterion 0.11281209230847522 B1_offset 0.2198343156733006
# Iteration 6  |W|_0  11 |E1|_0 10276  stopCriterion 0.09269749130573365 B1_offset 0.2203419245730067
# Iteration 7  |W|_0  12 |E1|_0 16698  stopCriterion 0.07802666392984964 B1_offset 0.0
# Iteration 8  |W|_0  16 |E1|_0 23537  stopCriterion 0.07057329283918161 B1_offset 0.2213645900770101
# Iteration 9  |W|_0  21 |E1|_0 28993  stopCriterion 0.05584548990993043 B1_offset 0.22095555375333278
# Iteration 10  |W|_0  31 |E1|_0 33796  stopCriterion 0.04899079226763649 B1_offset 0.2213025449703282
# Iteration 11  |W|_0  46 |E1|_0 39223  stopCriterion 0.04212037304850145 B1_offset 0.2211188977706524
# Iteration 12  |W|_0  56 |E1|_0 46400  stopCriterion 0.03640211906829047 B1_offset 0.2207846163399215
# Iteration 13  |W|_0  75 |E1|_0 58888  stopCriterion 0.031102656588439078 B1_offset 0.2205502935915917
# Iteration 14  |W|_0  103 |E1|_0 79918  stopCriterion 0.025689131997416313 B1_offset 0.22036985832569764
# Iteration 15  |W|_0  134 |E1|_0 112813  stopCriterion 0.020446837998730403 B1_offset 0.2202643075290375
# Iteration 16  |W|_0  171 |E1|_0 158813  stopCriterion 0.015340357967590233 B1_offset 0.22022416898194125
# Iteration 17  |W|_0  207 |E1|_0 211918  stopCriterion 0.010935057950486741 B1_offset 0.22022266282015474
# Iteration 18  |W|_0  237 |E1|_0 266831  stopCriterion 0.007478607527478919 B1_offset 0.22024438315680525
# Iteration 19  |W|_0  253 |E1|_0 318375  stopCriterion 0.004976823599329025 B1_offset 0.22027237697847943
# Iteration 20  |W|_0  260 |E1|_0 365026  stopCriterion 0.003319996237830214 B1_offset 0.22030153156533488
# Iteration 21  |W|_0  265 |E1|_0 407251  stopCriterion 0.002264739088029614 B1_offset 0.22032964769498165
# Iteration 22  |W|_0  272 |E1|_0 446794  stopCriterion 0.0016002901138357777 B1_offset 0.2203494721719533
# Iteration 23  |W|_0  280 |E1|_0 488516  stopCriterion 0.0011672638966631896 B1_offset 0.22036328923731152
# Iteration 24  |W|_0  285 |E1|_0 543400  stopCriterion 0.0008537242182105928 B1_offset 0.2203717298975575
# Iteration 25  |W|_0  295 |E1|_0 616183  stopCriterion 0.0006020952153786526 B1_offset 0.22037662173810024
# Iteration 26  |W|_0  298 |E1|_0 698199  stopCriterion 0.00040183151228403513 B1_offset 0.22037879098881577
# Iteration 27  |W|_0  301 |E1|_0 777329  stopCriterion 0.0002545184723031485 B1_offset 0.22037944957219835
# Iteration 28  |W|_0  305 |E1|_0 846194  stopCriterion 0.00015373423176901816 B1_offset 0.22037952758252644
# Iteration 29  |W|_0  314 |E1|_0 900516  stopCriterion 8.960052560570276e-05 B1_offset 0.22037926524557147
# Iteration 30  |W|_0  315 |E1|_0 940640  stopCriterion 5.084505611924862e-05 B1_offset 0.2203789657725355
# Iteration 31  |W|_0  319 |E1|_0 969592  stopCriterion 2.833302511644545e-05 B1_offset 0.22037872263556735
# Iteration 32  |W|_0  321 |E1|_0 989503  stopCriterion 1.558936089910409e-05 B1_offset 0.22037857717007797
# Iteration 33  |W|_0  324 |E1|_0 1003242  stopCriterion 8.528366765381492e-06 B1_offset 0.22037848181878306
# Iteration 34  |W|_0  326 |E1|_0 1012547  stopCriterion 4.69696482814038e-06 B1_offset 0.22037841803390715
# Iteration 35  |W|_0  326 |E1|_0 1018780  stopCriterion 2.567275723703271e-06 B1_offset 0.22037837507312633
# Iteration 36  |W|_0  327 |E1|_0 1022997  stopCriterion 1.4316335270513598e-06 B1_offset 0.22037834815495477
# Iteration 37  |W|_0  327 |E1|_0 1026037  stopCriterion 7.854122855037718e-07 B1_offset 0.22037833142964686
# Reweighting Iteration 3
# Iteration 1  |W|_0  1 |E1|_0 237  stopCriterion 0.6858912146249441 B1_offset 0.0
# Iteration 2  |W|_0  1 |E1|_0 280  stopCriterion 0.21115995308130472 B1_offset 0.0
# Iteration 3  |W|_0  4 |E1|_0 1009  stopCriterion 0.1760949353080271 B1_offset 0.21944447815231638
# Iteration 4  |W|_0  4 |E1|_0 2996  stopCriterion 0.12597219669532728 B1_offset 0.21954680541198413
# Iteration 5  |W|_0  8 |E1|_0 6170  stopCriterion 0.11172868433726338 B1_offset 0.21996845991204053
# Iteration 6  |W|_0  11 |E1|_0 10946  stopCriterion 0.09129021002074357 B1_offset 0.2205213041346991
# Iteration 7  |W|_0  12 |E1|_0 17014  stopCriterion 0.07715513072729847 B1_offset 0.11740940868768358
# Iteration 8  |W|_0  15 |E1|_0 23492  stopCriterion 0.0667228479552523 B1_offset 0.22089994511192448
# Iteration 9  |W|_0  21 |E1|_0 28525  stopCriterion 0.05520983026135264 B1_offset 0.2208290810776656
# Iteration 10  |W|_0  32 |E1|_0 32420  stopCriterion 0.04883423000025809 B1_offset 0.221152796184086
# Iteration 11  |W|_0  46 |E1|_0 37235  stopCriterion 0.04219568667301194 B1_offset 0.2209934347792388
# Iteration 12  |W|_0  57 |E1|_0 44835  stopCriterion 0.03639258934059023 B1_offset 0.22067962910094185
# Iteration 13  |W|_0  74 |E1|_0 58012  stopCriterion 0.03092254463693976 B1_offset 0.22044273805584103
# Iteration 14  |W|_0  104 |E1|_0 79323  stopCriterion 0.02541138914957917 B1_offset 0.2202720151268382
# Iteration 15  |W|_0  133 |E1|_0 111687  stopCriterion 0.020179077489735204 B1_offset 0.22018838060849746
# Iteration 16  |W|_0  173 |E1|_0 156810  stopCriterion 0.015250421727507273 B1_offset 0.2201747861193962
# Iteration 17  |W|_0  204 |E1|_0 210142  stopCriterion 0.010922718892568172 B1_offset 0.2201845770427781
# Iteration 18  |W|_0  235 |E1|_0 265185  stopCriterion 0.0074538244005272715 B1_offset 0.22020239743115444
# Iteration 19  |W|_0  249 |E1|_0 316565  stopCriterion 0.0049649595499045365 B1_offset 0.22023091299781983
# Iteration 20  |W|_0  256 |E1|_0 363298  stopCriterion 0.0033163424508666013 B1_offset 0.2202647273579447
# Iteration 21  |W|_0  259 |E1|_0 405862  stopCriterion 0.0022678765247063993 B1_offset 0.22029616123026913
# Iteration 22  |W|_0  271 |E1|_0 445293  stopCriterion 0.0016030505547148812 B1_offset 0.2203175442866613
# Iteration 23  |W|_0  276 |E1|_0 486465  stopCriterion 0.0011712678129040927 B1_offset 0.2203318762758956
# Iteration 24  |W|_0  285 |E1|_0 541325  stopCriterion 0.0008576903756733324 B1_offset 0.2203406436983114
# Iteration 25  |W|_0  292 |E1|_0 614611  stopCriterion 0.0006038353314246633 B1_offset 0.2203460043717817
# Iteration 26  |W|_0  299 |E1|_0 697052  stopCriterion 0.00040271169728192056 B1_offset 0.22034851396996044
# Iteration 27  |W|_0  302 |E1|_0 776608  stopCriterion 0.00025519789113174964 B1_offset 0.22034920505395286
# Iteration 28  |W|_0  309 |E1|_0 845733  stopCriterion 0.0001540847221810642 B1_offset 0.22034926233879518
# Iteration 29  |W|_0  309 |E1|_0 900271  stopCriterion 8.96277513271157e-05 B1_offset 0.22034899984195996
# Iteration 30  |W|_0  313 |E1|_0 940452  stopCriterion 5.078812169035041e-05 B1_offset 0.2203487068567595
# Iteration 31  |W|_0  314 |E1|_0 969312  stopCriterion 2.8378738689774644e-05 B1_offset 0.22034846880929843
# Iteration 32  |W|_0  319 |E1|_0 989407  stopCriterion 1.5613861642021538e-05 B1_offset 0.22034831936111388
# Iteration 33  |W|_0  318 |E1|_0 1003068  stopCriterion 8.556760506949015e-06 B1_offset 0.22034821834987492
# Iteration 34  |W|_0  322 |E1|_0 1012361  stopCriterion 4.699628266726292e-06 B1_offset 0.2203481480667678
# Iteration 35  |W|_0  321 |E1|_0 1018612  stopCriterion 2.591507080194722e-06 B1_offset 0.22034810381195125
# Iteration 36  |W|_0  323 |E1|_0 1022891  stopCriterion 1.435451663923957e-06 B1_offset 0.22034807449681493
# Iteration 37  |W|_0  324 |E1|_0 1025819  stopCriterion 7.916771184801384e-07 B1_offset 0.22034805500201385

# %% [markdown]
# ## Show output flatfield and darkfield components

# %%
print('Flatfield:')
plt.imshow(flatfield)
plt.colorbar()
plt.show()
print('Darkfield:')
plt.imshow(darkfield)
plt.colorbar()
plt.show()
# Out:
# Flatfield:
# Darkfield:

# %% [markdown]
# ## Correct image stack

# %%
D_corrected = np.transpose(D, (2,0,1))
D_corrected = np.array(D_corrected, dtype=np.float64)
D_corrected -= darkfield
D_corrected /= flatfield
D_corrected = np.transpose(D_corrected, (1,2,0))

# %% [markdown]
# # Show comparison between corrected and non-corrected images

# %%
plt.subplot(1,2,1)
plt.imshow(D[:,:,0])
plt.title('Uncorrected')
plt.subplot(1,2,2)
plt.imshow(D_corrected[:,:,0])
plt.title('Corrected')
plt.show()
